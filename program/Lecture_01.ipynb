# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\countries of the world.csv")

# %%
df.head()
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
# 4         Andorra   WESTERN EUROPE

# %%
df.shape
# Out:
# (227, 2)

# %%
df1 = pd.read_table(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\countries of the world.txt")
df1.head()
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
# 4         Andorra   WESTERN EUROPE

# %%
def read_cab(file_path):
    df = pd.read_csv(file_path, delimiter = ',')
    return df

file_path = r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\countries of the world.txt"
df = read_cab(file_path)
print(df.head(20))
# Out:
#                                       Country\tRegion
# 0         Afghanistan \tASIA (EX. NEAR EAST)
# 1       Albania \tEASTERN EUROPE
# 2       Algeria \tNORTHERN AFRICA
# 3   American Samoa \tOCEANIA                      ...
# 4       Andorra \tWESTERN EUROPE
# 5        Angola \tSUB-SAHARAN AFRICA
# 6                  Anguilla \tLATIN AMER. & CARIB
# 7         Antigua & Barbuda \tLATIN AMER. & CARIB
# 8                 Argentina \tLATIN AMER. & CARIB
# 9                      Armenia \tC.W. OF IND. STATES
# 10                    Aruba \tLATIN AMER. & CARIB
# 11    Australia \tOCEANIA
# 12      Austria \tWESTERN EUROPE
# 13                  Azerbaijan \tC.W. OF IND. STATES
# 14             Bahamas, The \tLATIN AMER. & CARIB
# 15      Bahrain \tNEAR EAST
# 16         Bangladesh \tASIA (EX. NEAR EAST)
# 17                 Barbados \tLATIN AMER. & CARIB
# 18                     Belarus \tC.W. OF IND. STATES
# 19      Belgium \tWESTERN EUROPE

# %%
df2 = pd.read_json(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\json_sample.json")
df2.head()
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df2 = pd.read_excel(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\world_population_excel_workbook.xlsx")
df2.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df2.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
df2.shape
# Out:
# (234, 17)

# %%
df2.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (kmÂ²)                    0
# Density (per kmÂ²)             0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df2.head(20)
# Out:
#     Rank CCA3              Country           Capital      Continent  \
# 0     36  AFG          Afghanistan             Kabul           Asia
# 1    138  ALB              Albania            Tirana         Europe
# 2     34  DZA              Algeria           Algiers         Africa
# 3    213  ASM       American Samoa         Pago Pago        Oceania
# 4    203  AND              Andorra  Andorra la Vella         Europe
# 5     42  AGO               Angola            Luanda         Africa
# 6    224  AIA             Anguilla        The Valley  North America
# 7    201  ATG  Antigua and Barbuda    Saint Johnâ€™s  North America
# 8     33  ARG            Argentina      Buenos Aires  South America
# 9    140  ARM              Armenia           Yerevan           Asia
# 10   198  ABW                Aruba        Oranjestad  North America
# 11    55  AUS            Australia          Canberra        Oceania
# 12    99  AUT              Austria            Vienna         Europe
# ...

# %%
df2.tail(10)
# Out:
#      Rank CCA3            Country       Capital      Continent  \
# 224    43  UZB         Uzbekistan      Tashkent           Asia
# 225   181  VUT            Vanuatu     Port-Vila        Oceania
# 226   234  VAT       Vatican City  Vatican City         Europe
# 227    51  VEN          Venezuela       Caracas  South America
# 228    16  VNM            Vietnam         Hanoi           Asia
# 229   226  WLF  Wallis and Futuna      Mata-Utu        Oceania
# 230   172  ESH     Western Sahara     El AaiÃºn         Africa
# 231    46  YEM              Yemen         Sanaa           Asia
# 232    63  ZMB             Zambia        Lusaka         Africa
# 233    74  ZWE           Zimbabwe        Harare         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 224         34627652         33526656         30949417         28614227
# 225           326740           311685           276438           245453
# ...

# %%
df2['Country']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
#              ...
# 229    Wallis and Futuna
# 230       Western Sahara
# 231                Yemen
# 232               Zambia
# 233             Zimbabwe
# Name: Country, Length: 234, dtype: object

# %%
row = df2.iloc[224, 2]
print(row)
# Out:
# Uzbekistan

# %%
row1 = df2.iloc[224]
print(row1)
# Out:
# Rank                                   43
# CCA3                                  UZB
# Country                        Uzbekistan
# Capital                          Tashkent
# Continent                            Asia
# 2022 Population                  34627652
# 2020 Population                  33526656
# 2015 Population                  30949417
# 2010 Population                  28614227
# 2000 Population                  24925554
# 1990 Population                  20579100
# 1980 Population                  15947129
# 1970 Population                  12011361
# Area (kmÂ²)                        447400
# Density (per kmÂ²)                77.3975
# Growth Rate                         1.016
# World Population Percentage          0.43
# Name: 224, dtype: object

# %%
data = df2.iloc[1:3, 2:4]

# %%
data
# Out:
#    Country  Capital
# 1  Albania   Tirana
# 2  Algeria  Algiers

# %%
table_01 = pd.read_csv(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\Table01.csv")
table_02 = pd.read_csv(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\Table02.csv")

# %%
table_01.head()
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
table_02
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
Inner_join = pd.merge(table_01, table_02, on ='FellowshipID', how = 'inner')

# %%
Inner_join
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0          1001       Frodo     Hiding       Frodo   50
# 1          1002     Samwise  Gardening     Samwise   39

# %%
OuterJoin_left = pd.merge(table_01, table_02, on = 'FellowshipID', how = 'left')

# %%
OuterJoin_left
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y   Age
# 0          1001       Frodo     Hiding       Frodo  50.0
# 1          1002     Samwise  Gardening     Samwise  39.0
# 2          1003     Gandalf     Spells         NaN   NaN
# 3          1004      Pippin  Fireworks         NaN   NaN

# %%
outerJoing_right = pd.merge(table_01, table_02, on= 'FellowshipID', how= 'right')

outerJoing_right
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y   Age
# 0          1001       Frodo     Hiding       Frodo    50
# 1          1002     Samwise  Gardening     Samwise    39
# 2          1006         NaN        NaN     Legolas  2931
# 3          1007         NaN        NaN      Elrond  6520
# 4          1008         NaN        NaN    Barromir    51

# %%
fullOuter_join = pd.merge(table_01, table_02, on = 'FellowshipID', how= 'outer')

fullOuter_join
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y     Age
# 0          1001       Frodo     Hiding       Frodo    50.0
# 1          1002     Samwise  Gardening     Samwise    39.0
# 2          1003     Gandalf     Spells         NaN     NaN
# 3          1004      Pippin  Fireworks         NaN     NaN
# 4          1006         NaN        NaN     Legolas  2931.0
# 5          1007         NaN        NaN      Elrond  6520.0
# 6          1008         NaN        NaN    Barromir    51.0

# %%
indexes_join = pd.merge(table_01, table_02, left_index= True, right_index= True)

indexes_join
# Out:
#    FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0            1001       Frodo     Hiding            1001       Frodo    50
# 1            1002     Samwise  Gardening            1002     Samwise    39
# 2            1003     Gandalf     Spells            1006     Legolas  2931
# 3            1004      Pippin  Fireworks            1007      Elrond  6520
