# %%
import pandas as pd

# %%
data_frame = pd.read_csv(r"D:\Second year second semester\Python for data science\Data Set\Data Sets-20240826\pokemon.csv")

# %%
data_frame.shape
# Out:
# (801, 41)

# %%
data_frame.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
data_frame.tail()
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %% [markdown]
# Find Average hp

# %%
data_frame['hp']
# Out:
# 0       45
# 1       60
# 2       80
# 3       39
# 4       58
#       ...
# 796     97
# 797     59
# 798    223
# 799     97
# 800     80
# Name: hp, Length: 801, dtype: int64

# %%
data_frame[['hp', 'attack', 'defense']].mean()
# Out:
# hp         68.958801
# attack     77.857678
# defense    73.008739
# dtype: float64

# %% [markdown]
# Display only fire-type pokemon in columns 'name', 'type1', 'hp', 'attack'

# %%
data_filtering = data_frame[data_frame['type1'] == 'fire'][['name', 'hp', 'attack']].head()

print(data_filtering)
# Out:
#           name  hp  attack
# 3   Charmander  39      52
# 4   Charmeleon  58      64
# 5    Charizard  78     104
# 36      Vulpix  38      41
# 37   Ninetales  73      67

# %% [markdown]
# How many pokemon are there for each type in the Type1 column

# %%
data_frame['type1'].value_counts()
# Out:
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %%
data_frame[data_frame['attack'] > 100][['attack', 'name']]
# Out:
#      attack        name
# 5       104   Charizard
# 8       103   Blastoise
# 14      150    Beedrill
# 33      102    Nidoking
# 56      105    Primeape
# ..      ...         ...
# 794     137   Pheromosa
# 796     101  Celesteela
# 797     181     Kartana
# 798     101    Guzzlord
# 799     107    Necrozma
#
# [169 rows x 2 columns]

# %% [markdown]
# Create a copy of orginal data frame

# %%
data_frame01 = data_frame.copy()

# %% [markdown]
# Rename the column

# %%
data_frame01 = data_frame01.rename(columns= {'hp':'health', 'attack': 'atk', 'defense':'def'})

# %%
data_frame01['atk'].head()
# Out:
# 0     49
# 1     62
# 2    100
# 3     52
# 4     64
# Name: atk, dtype: int64

# %%
data_frame01['total'] = data_frame01[['hp', 'attack', 'defense', 'speed']].sum(axis= 1)

# %%
data_frame01['total'].head(30)
# Out:
# 0     188
# 1     245
# 2     383
# 3     199
# 4     260
# 5     360
# 6     200
# 7     260
# 8     380
# 9     155
# 10    155
# 11    225
# 12    155
# 13    155
# 14    400
# 15    181
# 16    249
# 17    364
# 18    193
# 19    293
# 20    200
# 21    320
# 22    194
# 23    304
# 24    220
# 25    305
# 26    255
# 27    360
# 28    195
# 29    255
# Name: total, dtype: int64

# %%
data_frame01[data_frame01['is_legendary'] == True].head(20)
# Out:
#                          abilities  against_bug  against_dark  against_dragon  \
# 143     ['Pressure', 'Snow Cloak']         0.50           1.0             1.0
# 144         ['Pressure', 'Static']         0.50           1.0             1.0
# 145     ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 149        ['Pressure', 'Unnerve']         2.00           2.0             1.0
# 150                ['Synchronize']         2.00           2.0             1.0
# 242    ['Pressure', 'Inner Focus']         1.00           1.0             1.0
# 243    ['Pressure', 'Inner Focus']         0.50           1.0             1.0
# 244    ['Pressure', 'Inner Focus']         1.00           1.0             1.0
# 248     ['Pressure', 'Multiscale']         1.00           2.0             1.0
# 249    ['Pressure', 'Regenerator']         0.25           1.0             1.0
# 250               ['Natural Cure']         4.00           2.0             1.0
# ...

# %%
data_frame01[['attack', 'defense']].mean()
# Out:
# attack     77.857678
# defense    73.008739
# dtype: float64
